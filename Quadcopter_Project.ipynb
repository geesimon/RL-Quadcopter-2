# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [-2.11790127 14.93522939 27.30150398  0.61919674  0.28269228  0.        ]
# [-2.37385682 10.55977457  2.59503347]
# [0.11563517 0.23746499 0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 1000
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode = 1000, score =  -2.806 (best =   0.020), noise_scale = 3.25

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
## TODO: Train your agent here.
from task import MoveToTask
from agents.ddpg_agent import DDPGAgent

num_episodes = 1000
target_pos = np.array([100., 100., 100.])
task = MoveToTask(target_pos=target_pos)
agent = DDPGAgent(task)
rewards = np.zeros(num_episodes)
positions = np.zeros((num_episodes, 3))
path = None

for i_episode in range(num_episodes):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state)
        next_state, reward, done = task.step(action)
        #print(reward)
        agent.step(action, reward, next_state, done)
        state = next_state
        if done:
            rewards[i_episode],  path = agent.get_score()
            dist = task.get_distance(task.sim.pose[0:3], task.target_pos)
            sys.stdout.flush()
            print("\rEpisode = {:4d}, score = {:7.3f} distance = {:7.3f}".format(i_episode + 1, 
                  rewards[i_episode], dist), end="")
            break
# Out:
# C:\Users\geesi\Anaconda3\envs\dlnd\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# crash
# crash
# Episode =    1, score =  35.757 distance = 170.005crash
# crash
# Episode =    2, score =   6.752 distance = 171.796crash
# crash
# Episode =    3, score =   3.329 distance = 172.519crash
# crash
# Episode =    4, score =   2.650 distance = 173.387crash
# Episode =    5, score =  82.876 distance = 204.320crash
# crash
# Episode =    6, score =   4.770 distance = 173.073crash
# crash
# Episode =    7, score =   4.824 distance = 172.899crash
# crash
# Episode =    8, score =   2.823 distance = 172.965crash
# crash
# Episode =    9, score =   4.949 distance = 172.813crash
# crash
# Episode =   10, score =   4.970 distance = 172.898crash
# crash
# Episode =   11, score =   4.965 distance = 172.896crash
# crash
# Episode =   12, score =   4.964 distance = 172.901crash
# crash
# Episode =   13, score =   4.960 distance = 172.899crash
# crash
# Episode =   14, score =   4.906 distance = 172.880crash
# crash
# Episode =   15, score =   4.924 distance = 172.882crash
# crash
# Episode =   78, score =  90.708 distance = 128.236crash
# crash
# Episode =   79, score =  11.274 distance = 177.309crash
# crash
# Episode =   80, score =  11.484 distance = 177.354crash
# crash
# Episode =   81, score =  11.892 distance = 177.372crash
# crash
# Episode =   82, score =  11.489 distance = 177.328crash
# crash
# Episode =   83, score =  11.900 distance = 177.358crash
# crash
# Episode =   84, score =  12.088 distance = 177.268crash
# crash
# Episode =   85, score =  11.671 distance = 177.331crash
# crash
# Episode =   86, score =  11.035 distance = 177.331crash
# crash
# Episode =   87, score =  11.090 distance = 177.311crash
# crash
# Episode =   88, score =  11.537 distance = 177.303crash
# crash
# Episode =   89, score =  10.733 distance = 177.366crash
# crash
# Episode =   90, score =  11.278 distance = 177.320crash
# crash
# Episode =   91, score =  11.951 distance = 177.331crash
# crash
# Episode =   92, score =  10.302 distance = 177.332crash
# crash
# Episode =   93, score =  12.143 distance = 177.342crash
# crash
# Episode =   94, score =  11.117 distance = 177.358crash
# crash
# Episode =   95, score =  11.655 distance = 177.322crash
# crash
# Episode =   96, score =  11.235 distance = 177.315crash
# crash
# Episode =   97, score =  11.083 distance = 177.298crash
# crash
# Episode =   98, score =  10.856 distance = 177.376crash
# crash
# Episode =   99, score =  11.737 distance = 177.265crash
# crash
# Episode =  100, score =  10.928 distance = 177.311crash
# crash
# Episode =  101, score =  11.364 distance = 177.310crash
# crash
# Episode =  102, score =  11.968 distance = 177.330crash
# crash
# Episode =  103, score =  11.029 distance = 177.370crash
# crash
# Episode =  104, score =  11.716 distance = 177.325crash
# crash
# Episode =  105, score =  11.358 distance = 177.366crash
# crash
# Episode =  106, score =  11.060 distance = 177.316crash
# crash
# Episode =  107, score =  10.790 distance = 177.327crash
# crash
# Episode =  108, score =  10.294 distance = 177.354crash
# crash
# Episode =  109, score =  11.110 distance = 177.360crash
# crash
# Episode =  110, score =  12.034 distance = 177.306crash
# crash
# Episode =  111, score =  11.305 distance = 177.330crash
# crash
# Episode =  112, score =  11.432 distance = 177.342crash
# crash
# Episode =  113, score =  11.464 distance = 177.320crash
# crash
# Episode =  114, score =  10.945 distance = 177.375crash
# crash
# Episode =  115, score =  10.560 distance = 177.332crash
# crash
# Episode =  116, score =  12.012 distance = 177.341crash
# crash
# Episode =  117, score =  11.737 distance = 177.272crash
# crash
# Episode =  118, score =  10.862 distance = 177.306crash
# crash
# Episode =  119, score =  11.432 distance = 177.300crash
# crash
# Episode =  120, score =  10.834 distance = 177.339crash
# crash
# Episode =  121, score =  10.585 distance = 177.287crash
# crash
# Episode =  122, score =  11.469 distance = 177.360crash
# crash
# Episode =  123, score =  12.144 distance = 177.319crash
# crash
# Episode =  124, score =  11.601 distance = 177.318crash
# crash
# Episode =  125, score =  11.384 distance = 177.308crash
# crash
# Episode =  126, score =  10.250 distance = 177.317crash
# crash
# Episode =  127, score =  11.979 distance = 177.309crash
# crash
# Episode =  128, score =  12.363 distance = 177.265crash
# crash
# Episode =  129, score =  11.731 distance = 177.333crash
# crash
# Episode =  130, score =  10.754 distance = 177.351crash
# crash
# Episode =  131, score =  10.881 distance = 177.303crash
# crash
# Episode =  132, score =  11.252 distance = 177.323crash
# crash
# Episode =  133, score =  11.016 distance = 177.354crash
# crash
# Episode =  134, score =  11.262 distance = 177.352crash
# crash
# Episode =  135, score =  10.748 distance = 177.327crash
# crash
# Episode =  136, score =  11.413 distance = 177.308crash
# crash
# Episode =  137, score =  10.735 distance = 177.317crash
# crash
# Episode =  138, score =  10.842 distance = 177.395crash
# crash
# Episode =  139, score =  11.551 distance = 177.346crash
# crash
# Episode =  140, score =  10.671 distance = 177.296crash
# crash
# Episode =  141, score =  12.116 distance = 177.295crash
# crash
# Episode =  142, score =  11.036 distance = 177.333crash
# crash
# Episode =  143, score =  10.829 distance = 177.372crash
# crash
# Episode =  144, score =  11.544 distance = 177.322crash
# crash
# Episode =  145, score =  11.067 distance = 177.331crash
# crash
# Episode =  146, score =  10.181 distance = 177.337crash
# crash
# Episode =  147, score =  11.375 distance = 177.336crash
# crash
# Episode =  148, score =  10.947 distance = 177.327crash
# crash
# Episode =  149, score =  12.315 distance = 177.315crash
# crash
# Episode =  150, score =  11.196 distance = 177.388crash
# crash
# Episode =  151, score =  11.084 distance = 177.386crash
# crash
# Episode =  152, score =  10.363 distance = 177.335crash
# crash
# Episode =  153, score =  10.794 distance = 177.291crash
# crash
# Episode =  154, score =  11.517 distance = 177.283crash
# crash
# Episode =  155, score =  12.003 distance = 177.289crash
# crash
# Episode =  156, score =  11.499 distance = 177.325crash
# crash
# Episode =  157, score =  11.225 distance = 177.339crash
# crash
# Episode =  158, score =  12.299 distance = 177.293crash
# crash
# Episode =  159, score =  11.593 distance = 177.329crash
# crash
# Episode =  160, score =  11.422 distance = 177.303crash
# crash
# Episode =  161, score =  11.504 distance = 177.355crash
# crash
# Episode =  162, score =  12.094 distance = 177.317crash
# crash
# Episode =  163, score =   9.905 distance = 177.305crash
# crash
# Episode =  164, score =  10.871 distance = 177.352crash
# crash
# Episode =  165, score =  10.832 distance = 177.361crash
# crash
# Episode =  166, score =  10.777 distance = 177.353crash
# crash
# Episode =  167, score =  10.650 distance = 177.362crash
# crash
# Episode =  168, score =  11.464 distance = 177.337crash
# crash
# Episode =  169, score =  10.814 distance = 177.291crash
# crash
# Episode =  170, score =  11.874 distance = 177.364crash
# crash
# Episode =  171, score =  11.383 distance = 177.360crash
# crash
# Episode =  172, score =  11.838 distance = 177.328crash
# crash
# Episode =  173, score =  10.830 distance = 177.333crash
# crash
# Episode =  174, score =  11.336 distance = 177.329crash
# crash
# Episode =  175, score =  11.120 distance = 177.343crash
# crash
# Episode =  176, score =  11.675 distance = 177.308crash
# crash
# Episode =  177, score =  11.494 distance = 177.296crash
# crash
# Episode =  178, score =  11.520 distance = 177.317crash
# crash
# Episode =  179, score =  11.176 distance = 177.321crash
# crash
# Episode =  180, score =  11.358 distance = 177.342crash
# crash
# Episode =  181, score =  11.546 distance = 177.344crash
# crash
# Episode =  182, score =  11.893 distance = 177.298crash
# crash
# Episode =  183, score =  11.461 distance = 177.372crash
# crash
# Episode =  184, score =  11.451 distance = 177.297crash
# crash
# Episode =  185, score =  11.861 distance = 177.377crash
# crash
# Episode =  186, score =  10.999 distance = 177.320crash
# crash
# Episode =  187, score =  11.373 distance = 177.362crash
# crash
# Episode =  188, score =  10.748 distance = 177.382crash
# crash
# Episode =  189, score =  10.762 distance = 177.299crash
# crash
# Episode =  190, score =  11.258 distance = 177.318crash
# crash
# Episode =  191, score =  10.368 distance = 177.353crash
# crash
# Episode =  192, score =  10.678 distance = 177.352crash
# crash
# Episode =  193, score =  11.156 distance = 177.350crash
# crash
# Episode =  194, score =  12.011 distance = 177.309crash
# crash
# Episode =  195, score =  10.718 distance = 177.315crash
# crash
# Episode =  196, score =  11.597 distance = 177.347crash
# crash
# Episode =  197, score =  11.601 distance = 177.361crash
# crash
# Episode =  198, score =  10.912 distance = 177.344crash
# crash
# Episode =  199, score =  11.647 distance = 177.342crash
# crash
# Episode =  200, score =  11.431 distance = 177.339crash
# crash
# Episode =  201, score =  11.955 distance = 177.340crash
# crash
# Episode =  202, score =  11.523 distance = 177.327crash
# crash
# Episode =  203, score =  10.678 distance = 177.400crash
# crash
# Episode =  204, score =  11.632 distance = 177.346crash
# crash
# Episode =  205, score =  10.827 distance = 177.344crash
# crash
# Episode =  206, score =  11.826 distance = 177.328crash
# crash
# Episode =  207, score =  12.014 distance = 177.294crash
# crash
# Episode =  208, score =  11.116 distance = 177.318crash
# crash
# Episode =  209, score =  11.958 distance = 177.293crash
# crash
# Episode =  210, score =  10.739 distance = 177.354crash
# crash
# Episode =  211, score =  10.988 distance = 177.334crash
# crash
# Episode =  212, score =  12.029 distance = 177.319crash
# crash
# Episode =  213, score =  10.888 distance = 177.334crash
# crash
# Episode =  214, score =  10.853 distance = 177.336crash
# crash
# Episode =  215, score =  10.919 distance = 177.299crash
# crash
# Episode =  216, score =  10.929 distance = 177.371crash
# crash
# Episode =  217, score =  10.798 distance = 177.379crash
# crash
# Episode =  218, score =  11.341 distance = 177.355crash
# crash
# Episode =  219, score =  10.373 distance = 177.363crash
# crash
# Episode =  220, score =  10.778 distance = 177.321crash
# crash
# Episode =  221, score =  11.475 distance = 177.290crash
# crash
# Episode =  222, score =  11.503 distance = 177.316crash
# crash
# Episode =  223, score =  10.330 distance = 177.366crash
# crash
# Episode =  224, score =  11.858 distance = 177.287crash
# crash
# Episode =  225, score =  11.076 distance = 177.333crash
# crash
# Episode =  226, score =  10.432 distance = 177.331crash
# crash
# Episode =  227, score =  10.958 distance = 177.340crash
# crash
# Episode =  228, score =  12.179 distance = 177.308crash
# crash
# Episode =  229, score =  11.516 distance = 177.284crash
# crash
# Episode =  230, score =  10.855 distance = 177.278crash
# crash
# Episode =  231, score =  11.026 distance = 177.356crash
# crash
# Episode =  232, score =  12.002 distance = 177.302crash
# crash
# Episode =  233, score =  11.287 distance = 177.306crash
# crash
# Episode =  234, score =  11.109 distance = 177.360crash
# crash
# Episode =  235, score =  12.066 distance = 177.286crash
# crash
# Episode =  236, score =  11.685 distance = 177.353crash
# crash
# Episode =  237, score =  11.902 distance = 177.364crash
# crash
# Episode =  238, score =  11.520 distance = 177.306crash
# crash
# Episode =  239, score =  11.789 distance = 177.322crash
# crash
# Episode =  240, score =  12.025 distance = 177.336crash
# crash
# Episode =  241, score =  10.739 distance = 177.320crash
# crash
# Episode =  242, score =  11.202 distance = 177.336crash
# crash
# Episode =  243, score =  11.477 distance = 177.314crash
# crash
# Episode =  244, score =  10.804 distance = 177.351crash
# crash
# Episode =  245, score =  11.414 distance = 177.328crash
# crash
# Episode =  246, score =  11.785 distance = 177.337crash
# crash
# Episode =  247, score =  11.320 distance = 177.299crash
# crash
# Episode =  248, score =  11.990 distance = 177.355crash
# crash
# Episode =  249, score =  11.801 distance = 177.312crash
# crash
# Episode =  250, score =  10.855 distance = 177.309crash
# crash
# Episode =  251, score =  12.076 distance = 177.279crash
# crash
# Episode =  252, score =  12.152 distance = 177.297crash
# crash
# Episode =  253, score =  11.335 distance = 177.336crash
# crash
# Episode =  254, score =  12.367 distance = 177.304crash
# crash
# Episode =  255, score =  11.197 distance = 177.361crash
# crash
# Episode =  256, score =  10.693 distance = 177.299crash
# crash
# Episode =  257, score =  11.525 distance = 177.357crash
# crash
# Episode =  258, score =  11.169 distance = 177.351crash
# crash
# Episode =  259, score =  11.281 distance = 177.298crash
# crash
# Episode =  260, score =  10.938 distance = 177.356crash
# crash
# Episode =  261, score =  10.768 distance = 177.336crash
# crash
# Episode =  262, score =  11.434 distance = 177.383crash
# crash
# Episode =  263, score =  11.007 distance = 177.324crash
# crash
# Episode =  264, score =  12.104 distance = 177.303crash
# crash
# Episode =  265, score =  11.513 distance = 177.315crash
# crash
# Episode =  266, score =  10.939 distance = 177.303crash
# crash
# Episode =  267, score =  10.138 distance = 177.333crash
# crash
# Episode =  268, score =  11.640 distance = 177.336crash
# crash
# Episode =  269, score =  10.823 distance = 177.347crash
# crash
# Episode =  270, score =  10.734 distance = 177.309crash
# crash
# Episode =  271, score =  11.258 distance = 177.363crash
# crash
# Episode =  272, score =  11.416 distance = 177.311crash
# crash
# Episode =  273, score =  11.515 distance = 177.340crash
# crash
# Episode =  274, score =  11.240 distance = 177.363crash
# crash
# Episode =  275, score =  11.279 distance = 177.345crash
# crash
# Episode =  276, score =  10.846 distance = 177.338crash
# crash
# Episode =  277, score =  11.106 distance = 177.322crash
# crash
# Episode =  278, score =  11.313 distance = 177.335crash
# crash
# Episode =  279, score =  11.217 distance = 177.339crash
# crash
# Episode =  280, score =  11.705 distance = 177.324crash
# crash
# Episode =  281, score =  11.468 distance = 177.328crash
# crash
# Episode =  282, score =  11.463 distance = 177.347crash
# crash
# Episode =  283, score =  11.656 distance = 177.335crash
# crash
# Episode =  284, score =  10.969 distance = 177.363crash
# crash
# Episode =  285, score =  10.677 distance = 177.347crash
# crash
# Episode =  286, score =  11.516 distance = 177.292crash
# crash
# Episode =  287, score =  11.551 distance = 177.341crash
# crash
# Episode =  288, score =  10.804 distance = 177.342crash
# crash
# Episode =  289, score =  11.178 distance = 177.319crash
# crash
# Episode =  290, score =  11.330 distance = 177.332crash
# crash
# Episode =  291, score =  12.340 distance = 177.358crash
# crash
# Episode =  292, score =  11.104 distance = 177.308crash
# crash
# Episode =  293, score =  10.297 distance = 177.307crash
# crash
# Episode =  294, score =  10.914 distance = 177.340crash
# crash
# Episode =  295, score =  11.435 distance = 177.330crash
# crash
# Episode =  296, score =  12.099 distance = 177.258crash
# crash
# Episode =  297, score =  11.558 distance = 177.294crash
# crash
# Episode =  298, score =  11.058 distance = 177.340crash
# crash
# Episode =  299, score =  11.922 distance = 177.313crash
# crash
# Episode =  300, score =  11.501 distance = 177.305crash
# crash
# Episode =  301, score =  11.889 distance = 177.337crash
# crash
# Episode =  302, score =  11.175 distance = 177.362crash
# crash
# Episode =  303, score =  11.063 distance = 177.328crash
# crash
# Episode =  304, score =  11.872 distance = 177.300crash
# crash
# Episode =  305, score =  11.499 distance = 177.323crash
# crash
# Episode =  306, score =  11.042 distance = 177.356crash
# crash
# Episode =  307, score =  10.674 distance = 177.346crash
# crash
# Episode =  308, score =  11.393 distance = 177.330crash
# crash
# Episode =  309, score =  11.340 distance = 177.325crash
# crash
# Episode =  310, score =  12.065 distance = 177.323crash
# crash
# Episode =  311, score =  10.214 distance = 177.304crash
# crash
# Episode =  312, score =  11.725 distance = 177.292crash
# crash
# Episode =  313, score =  11.412 distance = 177.330crash
# crash
# Episode =  314, score =  10.641 distance = 177.290crash
# crash
# Episode =  315, score =  10.904 distance = 177.341crash
# crash
# Episode =  316, score =  11.460 distance = 177.325crash
# crash
# Episode =  317, score =  12.169 distance = 177.303crash
# crash
# Episode =  318, score =  11.461 distance = 177.308crash
# crash
# Episode =  319, score =  10.818 distance = 177.281crash
# crash
# Episode =  320, score =  12.151 distance = 177.328crash
# crash
# Episode =  321, score =  12.608 distance = 177.284crash
# crash
# Episode =  322, score =  11.148 distance = 177.349crash
# crash
# Episode =  323, score =  11.365 distance = 177.361crash
# crash
# Episode =  324, score =  11.721 distance = 177.353crash
# crash
# Episode =  325, score =  11.492 distance = 177.286crash
# crash
# Episode =  326, score =  11.082 distance = 177.366crash
# crash
# Episode =  327, score =  11.703 distance = 177.304crash
# crash
# Episode =  328, score =  11.340 distance = 177.392crash
# crash
# Episode =  329, score =  11.822 distance = 177.347crash
# crash
# Episode =  330, score =  11.463 distance = 177.315crash
# crash
# Episode =  331, score =  10.398 distance = 177.348crash
# crash
# Episode =  332, score =  10.755 distance = 177.364crash
# crash
# Episode =  333, score =  11.171 distance = 177.313crash
# crash
# Episode =  334, score =  11.431 distance = 177.314crash
# crash
# Episode =  335, score =  11.486 distance = 177.331crash
# crash
# Episode =  336, score =  10.697 distance = 177.322crash
# crash
# Episode =  337, score =  11.955 distance = 177.333crash
# crash
# Episode =  338, score =  12.084 distance = 177.298crash
# crash
# Episode =  339, score =  12.096 distance = 177.280crash
# crash
# Episode =  340, score =  11.732 distance = 177.315crash
# crash
# Episode =  341, score =  11.607 distance = 177.327crash
# crash
# Episode =  342, score =  11.385 distance = 177.313crash
# crash
# Episode =  343, score =  10.940 distance = 177.304crash
# crash
# Episode =  344, score =  10.870 distance = 177.313crash
# crash
# Episode =  345, score =  10.733 distance = 177.337crash
# crash
# Episode =  346, score =  10.744 distance = 177.315crash
# crash
# Episode =  347, score =  11.197 distance = 177.303crash
# crash
# Episode =  348, score =  10.823 distance = 177.364crash
# crash
# Episode =  349, score =  12.012 distance = 177.319crash
# crash
# Episode =  350, score =  11.546 distance = 177.347crash
# crash
# Episode =  351, score =  11.422 distance = 177.345crash
# crash
# Episode =  352, score =  11.551 distance = 177.318crash
# crash
# Episode =  353, score =  11.324 distance = 177.318crash
# crash
# Episode =  354, score =  11.482 distance = 177.351crash
# crash
# Episode =  355, score =  11.341 distance = 177.366crash
# crash
# Episode =  356, score =  11.533 distance = 177.316crash
# crash
# Episode =  357, score =  11.649 distance = 177.350crash
# crash
# Episode =  358, score =  11.902 distance = 177.318crash
# crash
# Episode =  359, score =  11.299 distance = 177.355crash
# crash
# Episode =  360, score =  10.287 distance = 177.395crash
# crash
# Episode =  361, score =  11.388 distance = 177.320crash
# crash
# Episode =  362, score =  10.684 distance = 177.362crash
# crash
# Episode =  363, score =  10.738 distance = 177.370crash
# crash
# Episode =  364, score =  10.877 distance = 177.312crash
# crash
# Episode =  365, score =  11.544 distance = 177.294crash
# crash
# Episode =  366, score =  11.510 distance = 177.327crash
# crash
# Episode =  367, score =  11.803 distance = 177.312crash
# crash
# Episode =  368, score =  11.336 distance = 177.351crash
# crash
# Episode =  369, score =  11.826 distance = 177.331crash
# crash
# Episode =  370, score =  11.380 distance = 177.317crash
# crash
# Episode =  371, score =  11.512 distance = 177.349crash
# crash
# Episode =  372, score =  11.626 distance = 177.341crash
# crash
# Episode =  373, score =  10.212 distance = 177.301crash
# crash
# Episode =  374, score =  10.943 distance = 177.334crash
# crash
# Episode =  375, score =  11.349 distance = 177.313crash
# crash
# Episode =  376, score =  10.967 distance = 177.365crash
# crash
# Episode =  377, score =  11.169 distance = 177.373crash
# crash
# Episode =  378, score =  11.481 distance = 177.300crash
# crash
# Episode =  379, score =  10.490 distance = 177.300crash
# crash
# Episode =  380, score =  11.734 distance = 177.308crash
# crash
# Episode =  381, score =  11.415 distance = 177.379crash
# crash
# Episode =  382, score =  12.293 distance = 177.298crash
# crash
# Episode =  383, score =  11.506 distance = 177.360crash
# crash
# Episode =  384, score =  12.537 distance = 177.264crash
# crash
# Episode =  385, score =  11.841 distance = 177.271crash
# crash
# Episode =  386, score =  11.342 distance = 177.369crash
# crash
# Episode =  387, score =  11.439 distance = 177.342crash
# crash
# Episode =  388, score =  11.504 distance = 177.334crash
# crash
# Episode =  389, score =  11.368 distance = 177.327crash
# crash
# Episode =  390, score =  11.411 distance = 177.330crash
# crash
# Episode =  391, score =  10.736 distance = 177.384crash
# crash
# Episode =  392, score =  11.959 distance = 177.282crash
# crash
# Episode =  393, score =  10.866 distance = 177.339crash
# crash
# Episode =  394, score =  10.888 distance = 177.374crash
# crash
# Episode =  395, score =  11.354 distance = 177.304crash
# crash
# Episode =  396, score =  11.563 distance = 177.276crash
# crash
# Episode =  397, score =  11.158 distance = 177.319crash
# crash
# Episode =  398, score =  11.538 distance = 177.291crash
# crash
# Episode =  399, score =  11.499 distance = 177.336crash
# crash
# Episode =  400, score =  11.890 distance = 177.281crash
# crash
# Episode =  401, score =  11.564 distance = 177.322crash
# crash
# Episode =  402, score =  11.284 distance = 177.309crash
# crash
# Episode =  403, score =  11.290 distance = 177.338crash
# crash
# Episode =  404, score =  11.400 distance = 177.348crash
# crash
# Episode =  405, score =  11.095 distance = 177.374crash
# crash
# Episode =  406, score =  11.348 distance = 177.342crash
# crash
# Episode =  407, score =  12.760 distance = 177.287crash
# crash
# Episode =  408, score =  11.457 distance = 177.332crash
# crash
# Episode =  409, score =  11.641 distance = 177.360crash
# crash
# Episode =  410, score =  10.448 distance = 177.336crash
# crash
# Episode =  411, score =  10.960 distance = 177.286crash
# crash
# Episode =  412, score =  12.173 distance = 177.300crash
# crash
# Episode =  413, score =  11.831 distance = 177.313crash
# crash
# Episode =  414, score =  12.036 distance = 177.285crash
# crash
# Episode =  415, score =  11.351 distance = 177.332crash
# crash
# Episode =  416, score =  11.789 distance = 177.310crash
# crash
# Episode =  417, score =  11.879 distance = 177.322crash
# crash
# Episode =  418, score =  11.406 distance = 177.288crash
# crash
# Episode =  419, score =  11.174 distance = 177.313crash
# crash
# Episode =  420, score =  12.159 distance = 177.274crash
# crash
# Episode =  421, score =  11.296 distance = 177.322crash
# crash
# Episode =  422, score =  10.823 distance = 177.285crash
# crash
# Episode =  423, score =  11.424 distance = 177.318crash
# crash
# Episode =  424, score =  10.869 distance = 177.330crash
# crash
# Episode =  425, score =  10.474 distance = 177.362crash
# crash
# Episode =  426, score =  10.753 distance = 177.338crash
# crash
# Episode =  427, score =  12.339 distance = 177.305crash
# crash
# Episode =  428, score =  10.877 distance = 177.336crash
# crash
# Episode =  429, score =  11.413 distance = 177.341crash
# crash
# Episode =  430, score =  11.372 distance = 177.360crash
# crash
# Episode =  431, score =  10.966 distance = 177.324crash
# crash
# Episode =  432, score =  11.520 distance = 177.302crash
# crash
# Episode =  433, score =  10.929 distance = 177.362crash
# crash
# Episode =  434, score =  12.272 distance = 177.267crash
# crash
# Episode =  435, score =  11.837 distance = 177.328crash
# crash
# Episode =  436, score =  10.884 distance = 177.312crash
# crash
# Episode =  437, score =  10.847 distance = 177.402crash
# crash
# Episode =  438, score =  11.323 distance = 177.303crash
# crash
# Episode =  439, score =  11.556 distance = 177.321crash
# crash
# Episode =  440, score =  12.128 distance = 177.300crash
# crash
# Episode =  441, score =  11.499 distance = 177.277crash
# crash
# Episode =  442, score =  11.208 distance = 177.332crash
# crash
# Episode =  443, score =  11.289 distance = 177.326crash
# crash
# Episode =  444, score =  10.867 distance = 177.331crash
# crash
# Episode =  445, score =  11.271 distance = 177.327crash
# crash
# Episode =  446, score =  11.457 distance = 177.304crash
# crash
# Episode =  447, score =  11.548 distance = 177.314crash
# crash
# Episode =  448, score =  11.171 distance = 177.328crash
# crash
# Episode =  449, score =  11.496 distance = 177.299crash
# crash
# Episode =  450, score =  11.290 distance = 177.326crash
# crash
# Episode =  451, score =  11.173 distance = 177.322crash
# crash
# Episode =  452, score =  11.325 distance = 177.369crash
# crash
# Episode =  453, score =  10.748 distance = 177.349crash
# crash
# Episode =  454, score =  10.633 distance = 177.323crash
# crash
# Episode =  455, score =  11.474 distance = 177.345crash
# crash
# Episode =  456, score =  10.966 distance = 177.325crash
# crash
# Episode =  457, score =  11.374 distance = 177.331crash
# crash
# Episode =  458, score =  10.701 distance = 177.334crash
# crash
# Episode =  459, score =  10.766 distance = 177.335crash
# crash
# Episode =  460, score =  11.489 distance = 177.319crash
# crash
# Episode =  461, score =  11.444 distance = 177.329crash
# crash
# Episode =  462, score =  10.539 distance = 177.292crash
# crash
# Episode =  463, score =  11.130 distance = 177.326crash
# crash
# Episode =  464, score =  10.923 distance = 177.310crash
# crash
# Episode =  465, score =  11.053 distance = 177.350crash
# crash
# Episode =  466, score =  10.708 distance = 177.321crash
# crash
# Episode =  467, score =   9.932 distance = 177.330crash
# crash
# Episode =  468, score =  11.916 distance = 177.293crash
# Episode =  478, score =  90.704 distance = 133.578crash
# Episode =  479, score =  23.120 distance = 171.564crash
# crash
# Episode =  481, score =  91.602 distance = 159.798crash
# Episode =  482, score =  17.131 distance = 187.223crash
# crash
# Episode =  483, score =  29.351 distance = 170.250crash
# Episode =  484, score =  91.602 distance = 165.344crash
# Episode =  485, score =  12.248 distance = 174.674crash
# crash
# Episode =  486, score =  11.218 distance = 174.232crash
# crash
# Episode =  487, score =  11.649 distance = 174.629crash
# crash
# Episode =  488, score =  11.061 distance = 174.503crash
# crash
# Episode =  489, score =  11.051 distance = 174.427crash
# crash
# Episode =  490, score =  11.120 distance = 174.246crash
# crash
# Episode =  491, score =  10.924 distance = 174.347crash
# crash
# Episode =  492, score =   9.282 distance = 175.063crash
# crash
# Episode =  493, score =  14.415 distance = 177.877crash
# crash
# Episode =  494, score =   9.785 distance = 175.009crash
# crash
# Episode =  495, score =  11.269 distance = 174.217crash
# crash
# Episode =  496, score =  10.460 distance = 174.419crash
# crash
# Episode =  497, score =  13.754 distance = 174.830crash
# crash
# Episode =  498, score =   8.939 distance = 174.820crash
# crash
# Episode =  499, score =  11.274 distance = 174.286crash
# crash
# Episode =  500, score =  11.129 distance = 174.296crash
# crash
# Episode =  501, score =  11.163 distance = 174.201crash
# crash
# Episode =  502, score =  11.070 distance = 174.281crash
# crash
# Episode =  503, score =  11.217 distance = 174.312crash
# crash
# Episode =  504, score =  11.059 distance = 174.328crash
# crash
# Episode =  505, score =  11.048 distance = 174.357crash
# crash
# Episode =  506, score =  13.851 distance = 174.844crash
# crash
# Episode =  507, score =  12.694 distance = 174.372crash
# crash
# Episode =  508, score =  10.420 distance = 174.394crash
# crash
# Episode =  509, score =  11.109 distance = 174.264crash
# crash
# Episode =  510, score =  11.218 distance = 174.286crash
# crash
# Episode =  511, score =  11.090 distance = 174.330crash
# crash
# Episode =  512, score =  11.151 distance = 174.278crash
# crash
# Episode =  513, score =  11.276 distance = 174.324crash
# crash
# Episode =  514, score =  10.485 distance = 174.290crash
# crash
# Episode =  515, score =  11.155 distance = 174.259crash
# crash
# Episode =  516, score =  11.150 distance = 174.257crash
# crash
# Episode =  517, score =  11.181 distance = 174.256crash
# crash
# Episode =  518, score =  11.210 distance = 174.318crash
# crash
# Episode =  519, score =  11.134 distance = 174.322crash
# crash
# Episode =  520, score =  11.144 distance = 174.264crash
# crash
# Episode =  521, score =  10.982 distance = 174.291crash
# crash
# Episode =  522, score =  11.025 distance = 174.288crash
# crash
# Episode =  523, score =  11.189 distance = 174.329crash
# crash
# Episode =  524, score =  11.172 distance = 174.252crash
# crash
# Episode =  525, score =  11.127 distance = 174.338crash
# crash
# Episode =  526, score =  11.173 distance = 174.326crash
# crash
# Episode =  527, score =  11.198 distance = 174.282crash
# crash
# Episode =  528, score =  11.037 distance = 174.313crash
# crash
# Episode =  529, score =  11.158 distance = 174.278crash
# crash
# Episode =  530, score =  11.163 distance = 174.348crash
# crash
# Episode =  531, score =  10.969 distance = 174.297crash
# crash
# Episode =  532, score =  11.085 distance = 174.276crash
# crash
# Episode =  533, score =  11.173 distance = 174.257crash
# crash
# Episode =  534, score =  10.997 distance = 174.299crash
# crash
# Episode =  535, score =  11.158 distance = 174.245crash
# crash
# Episode =  536, score =  11.081 distance = 174.347crash
# crash
# Episode =  537, score =  11.063 distance = 174.277crash
# crash
# Episode =  538, score =  11.106 distance = 174.357crash
# crash
# Episode =  539, score =  11.217 distance = 174.296crash
# crash
# Episode =  540, score =  11.025 distance = 174.299crash
# crash
# Episode =  541, score =  10.971 distance = 174.324crash
# crash
# Episode =  542, score =  11.345 distance = 174.251crash
# crash
# Episode =  543, score =  11.239 distance = 174.234crash
# crash
# Episode =  544, score =  11.180 distance = 174.326crash
# crash
# Episode =  545, score =  11.054 distance = 174.222crash
# crash
# Episode =  546, score =  11.106 distance = 174.258crash
# crash
# Episode =  547, score =  11.136 distance = 174.293crash
# crash
# Episode =  548, score =  11.178 distance = 174.254crash
# crash
# Episode =  549, score =  14.622 distance = 174.581crash
# crash
# Episode =  550, score =  13.876 distance = 174.998crash
# crash
# Episode =  551, score =  11.127 distance = 174.302crash
# crash
# Episode =  552, score =  11.114 distance = 174.282crash
# crash
# Episode =  553, score =  10.997 distance = 168.541crash
# crash
# Episode =  554, score =  19.439 distance = 165.492crash
# crash
# Episode =  555, score =  13.543 distance = 175.392crash
# crash
# Episode =  556, score =  16.212 distance = 174.286crash
# crash
# Episode =  557, score =  15.180 distance = 174.256crash
# crash
# Episode =  558, score =   9.709 distance = 175.088crash
# crash
# Episode =  559, score =  11.224 distance = 174.763crash
# crash
# Episode =  560, score =  12.713 distance = 174.582crash
# crash
# Episode =  561, score =  13.231 distance = 174.664crash
# crash
# Episode =  562, score =  10.972 distance = 174.313crash
# crash
# Episode =  563, score =  11.003 distance = 174.303crash
# crash
# Episode =  564, score =  11.036 distance = 174.289crash
# crash
# Episode =  565, score =  10.645 distance = 174.363crash
# crash
# Episode =  566, score =  10.383 distance = 174.696crash
# crash
# Episode =  567, score =  10.335 distance = 174.457crash
# crash
# Episode =  568, score =  11.319 distance = 174.085crash
# crash
# Episode =  569, score =  10.485 distance = 174.416crash
# crash
# Episode =  570, score =  10.923 distance = 174.360crash
# crash
# Episode =  571, score =  11.027 distance = 174.294crash
# crash
# Episode =  572, score =  11.177 distance = 174.245crash
# crash
# Episode =  573, score =  11.213 distance = 174.221crash
# crash
# Episode =  574, score =  11.144 distance = 174.262crash
# crash
# Episode =  575, score =  11.070 distance = 174.289crash
# crash
# Episode =  576, score =  11.108 distance = 174.261crash
# crash
# Episode =  577, score =  11.071 distance = 174.349crash
# crash
# Episode =  578, score =  11.197 distance = 174.304crash
# crash
# Episode =  579, score =  11.040 distance = 174.265crash
# crash
# Episode =  580, score =  11.119 distance = 174.285crash
# crash
# Episode =  581, score =  21.723 distance = 169.585crash
# crash
# Episode =  582, score =  11.093 distance = 174.297crash
# crash
# Episode =  583, score =  11.180 distance = 174.255crash
# crash
# Episode =  584, score =  12.537 distance = 175.097crash
# crash
# Episode =  585, score =  10.983 distance = 174.297crash
# crash
# Episode =  586, score =   9.421 distance = 170.264crash
# crash
# Episode =  587, score =  11.083 distance = 174.282crash
# crash
# Episode =  588, score =  11.047 distance = 174.307crash
# crash
# Episode =  589, score =  11.045 distance = 174.296crash
# crash
# Episode =  590, score =  15.761 distance = 174.508crash
# crash
# Episode =  591, score =  11.257 distance = 174.255crash
# crash
# Episode =  592, score =  10.974 distance = 174.313crash
# crash
# Episode =  593, score =  11.067 distance = 174.282crash
# crash
# Episode =  594, score =  11.121 distance = 174.270crash
# crash
# Episode =  595, score =  11.082 distance = 174.275crash
# crash
# Episode =  596, score =  11.112 distance = 174.346crash
# crash
# Episode =  597, score =  11.121 distance = 174.270crash
# crash
# Episode =  598, score =  11.009 distance = 174.367crash
# crash
# Episode =  599, score =  11.022 distance = 174.289crash
# crash
# Episode =  600, score =  11.114 distance = 174.253crash
# crash
# Episode =  601, score =  11.179 distance = 174.266crash
# crash
# Episode =  602, score =  11.120 distance = 174.272crash
# crash
# Episode =  603, score =  11.082 distance = 174.340crash
# crash
# Episode =  604, score =  10.916 distance = 174.342crash
# crash
# Episode =  605, score =  10.992 distance = 174.327crash
# crash
# Episode =  606, score =  11.083 distance = 174.281crash
# crash
# Episode =  607, score =  11.186 distance = 174.263crash
# crash
# Episode =  608, score =  10.973 distance = 174.306crash
# crash
# Episode =  609, score =  10.962 distance = 174.318crash
# crash
# Episode =  610, score =  10.993 distance = 174.302crash
# crash
# Episode =  611, score =  11.089 distance = 174.350crash
# crash
# Episode =  612, score =  11.179 distance = 174.254crash
# crash
# Episode =  613, score =  11.144 distance = 174.271crash
# crash
# Episode =  614, score =  11.119 distance = 174.277crash
# crash
# Episode =  615, score =  11.040 distance = 174.286crash
# Episode =  616, score =  90.708 distance = 132.596crash
# Episode =  619, score =  90.707 distance = 150.170crash
# Episode =  620, score =   7.703 distance = 180.552crash
# Episode =  621, score =   7.164 distance = 180.425crash
# Episode =  622, score =  13.307 distance = 180.840crash
# crash
# Episode =  623, score =  10.505 distance = 180.631crash
# Episode =  625, score =  86.534 distance = 207.230crash
# Episode =  626, score =  24.159 distance = 191.792crash
# crash
# Episode =  627, score =  22.037 distance = 181.515crash
# Episode =  628, score =  90.708 distance = 159.695crash
# Episode =  630, score =  90.707 distance = 146.144crash
# Episode =  631, score =  90.708 distance = 150.339crash
# Episode =  632, score =  23.684 distance = 181.383crash
# Episode =  718, score =  90.707 distance = 154.801crash
# Episode =  719, score =   7.040 distance = 162.575crash
# Episode =  720, score =   8.595 distance = 167.039crash
# crash
# Episode =  721, score =   8.773 distance = 167.054crash
# Episode =  722, score =   6.880 distance = 162.135crash
# crash
# Episode =  723, score =  23.246 distance = 162.995crash
# crash
# Episode =  724, score =  26.125 distance = 170.632crash
# crash
# Episode =  725, score =  18.504 distance = 170.663crash
# crash
# Episode =  726, score =   9.984 distance = 162.047crash
# Episode =  727, score =  90.710 distance = 146.481crash
# crash
# Episode =  728, score =  -3.996 distance = 171.783crash
# crash
# Episode =  729, score =  22.392 distance = 171.361crash
# Episode =  730, score =  79.951 distance = 140.925crash
# crash
# Episode =  731, score =  15.637 distance = 170.943crash
# crash
# Episode =  732, score =   8.150 distance = 160.872crash
# Episode =  733, score =  90.710 distance = 146.212crash
# crash
# Episode =  736, score =  90.706 distance = 135.120crash
# Episode =  737, score =  15.003 distance = 160.685crash
# crash
# Episode =  738, score =   9.619 distance = 163.131crash
# crash
# Episode =  739, score =  29.359 distance = 168.992crash
# crash
# Episode =  740, score =  15.521 distance = 170.832crash
# crash
# Episode =  741, score =   8.230 distance = 161.683crash
# Episode =  742, score =  90.707 distance = 130.312crash
# crash
# Episode =  744, score =  90.707 distance = 126.656crash
# crash
# Episode =  745, score =  18.746 distance = 168.290crash
# crash
# Episode =  746, score =  15.510 distance = 170.591crash
# Episode =  747, score =   7.405 distance = 161.752crash
# Episode =  748, score =  90.707 distance = 138.999crash
# Episode =  749, score =  90.707 distance = 123.355crash
# Episode =  750, score =  90.708 distance = 153.115crash
# crash
# Episode =  751, score =  11.111 distance = 159.192crash
# crash
# Episode =  754, score =  90.705 distance = 145.716crash
# crash
# Episode =  755, score =  15.503 distance = 169.762crash
# Episode =  756, score =  90.706 distance = 125.676crash
# crash
# Episode =  757, score =  53.422 distance = 162.443crash
# Episode =  758, score =  90.706 distance = 129.794crash
# crash
# Episode =  759, score =  13.147 distance = 179.104crash
# crash
# Episode =  760, score =  25.415 distance = 182.199crash
# crash
# Episode =  761, score =  -7.145 distance = 172.657crash
# crash
# Episode =  762, score =  17.611 distance = 171.512crash
# crash
# Episode =  763, score =   8.152 distance = 169.219crash
# Episode =  764, score =  90.706 distance = 141.657crash
# crash
# Episode =  765, score =  89.458 distance = 103.779crash
# crash
# Episode =  766, score =  17.067 distance = 170.860crash
# Episode =  767, score =  90.708 distance = 134.895crash
# crash
# Episode =  768, score =  22.896 distance = 172.367crash
# crash
# Episode =  769, score =  13.657 distance = 166.414crash
# crash
# Episode =  770, score =  64.554 distance = 158.035crash
# Episode =  771, score =   8.926 distance = 167.535crash
# Episode =  772, score =  64.046 distance = 176.943crash
# crash
# Episode =  773, score =  33.175 distance = 160.757crash
# crash
# Episode =  774, score =  23.166 distance = 168.408crash
# crash
# Episode =  775, score =  22.294 distance = 170.876crash
# crash
# Episode =  776, score =  44.795 distance = 168.565crash
# crash
# Episode =  777, score =  16.403 distance = 167.456crash
# crash
# Episode =  779, score =  90.707 distance = 141.307crash
# crash
# Episode =  780, score =  15.835 distance = 169.777crash
# crash
# Episode =  781, score =  16.164 distance = 158.035crash
# crash
# Episode =  782, score =  17.319 distance = 170.879crash
# crash
# Episode =  783, score =  15.330 distance = 171.254

# %%
from mpl_toolkits.mplot3d import axes3d, Axes3D

fig = plt.figure()
ax = Axes3D(fig)
#ax = fig.add_subplot(111, projection='3d')
ax.scatter(path[:,0], path[:,1], path[:,2])

# %%
plt.plot(positions[:,0], positions[:,1])
plt.xlabel('X')
plt.ylabel('Y')
_ = plt.ylim()

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
## TODO: Plot the rewards.
plt.plot(range(num_episodes), rewards)
plt.xlabel('Episode')
plt.ylabel('Return')
_ = plt.ylim()

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**:
# I designed a MoveToTask to move the droid to a target location (x,y,z). The reward function calculate how much closer each step gain. In addition, the task give a big reward if the target location is reached and penalize if the droid go out of boundry.

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:
#
# - I used DDPG algorithm as illusrated in the course and it supposed to work very well in continuous action and state spaces.
#
# - I used the default hyperparameters.
#
# - I used the default neural network architecture of the provided code.

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:
#
# - I guess my implmentation has some problem and the reward never converge. In addition, the droid seems just wondering around and can't reach the target location (please help me to understand what's wrong)
# - Tried 2000 episode but no converge.
# - The performance is not that good.

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
#
# - Given we already given the implementaion of the DDPG (which is hard), the design a good reward function design would be the most hard part for me.
# - The whole experience is very interesting and I do learned a lot in order to clue all pieces of code to work. I just hope I can have more time to work on this homework and have fun.
